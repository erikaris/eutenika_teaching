# %% [markdown]
# Before crawling twitter, we have to create api key and token. To do that, follow the instruction:
# - Open [Twitter Developers](https://developer.twitter.com/en/apps) using your twitter account
# - Create An Application
# - Follow on screen instruction and fill the required field
# - After application successfully created, go to tab ***"Keys and Tokens"***, then regenerate both "Consumer API keys" and "Access token & access token secret"
# - Copy the values here

# %%
consumer_key = 'mLsCOnq6zS0zYMmlKsL7apxg1'
consumer_secret = 'CAvaKgoGfaHVAScly9qalXaChpe26pTRbvkP73jGDNyxrdE0lH'
access_token = '2689318266-VvOQQCG8ObkBCe2Tu3JiQLu1dRhKoc9iU7c0QQo'
access_secret = 'OU1fn13kmwW8S3xpzo8f3k7wzMaEIooMr85cWNZea8mui'

# %% [markdown]
# Use above credentials to authenticate ```tweepy.API```. Before to do it, we have to make sure to install tweepy package ```pip install tweepy```

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %% [markdown]
# Make a search trough that API. We provide ***-filter:retweets*** in the search term to filter out the retweet tweet. Option ```tweet_mode='extended'``` is used to get the full text of tweet instead of 160 chars truncated tweet. Since twitter apply rate limit, we should provide ```wait_on_rate_limit=True``` option.

# %%
query = 'sensus penduduk 2020 -filter:retweets'
max_tweets = 1000

searched_tweets = [status.full_text.replace('\n', ' ') for status in
                   tweepy.Cursor(api.search, q=query, tweet_mode='extended',
                   wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
                   .items(max_tweets)]

# %% [markdown]
# See the result

# %%
searched_tweets
# Out:
# ['Ayo input data anda sebelum tanggal 31 Maret 2020. Etam sukseskan *Sensus Penduduk Online 2020* 👍  Sensus Penduduk 2020  #MencatatIndonesia #ProkomKukar  #KomitmentPemkabKukar  #KutaiKartanegara',
#  '@OdedMD @kangyanamulyana @KHamidipradja @NurShomaddin @HumasBdg @pembdg @coblongjitu  13 Maret 2020. Rapat Koordinasi Aparat Kelurahan Lebak Siliwangi dengan @bps_statistics  tentang Sosialisasi &amp; Pelaksanaan Sensus Penduduk Tahun 2020 secara Online. https://t.co/ZxJA1KB1ql',
#  'ASN DPMPTSP NAKER Melakukan Proses pengisian sensus penduduk secara online didampingi oleh petugas dari Badan Pusat Statistik Kabupaten Agam di ruang rapat Dinas PMPTSP NAKER tgl 13 maret 2020 https://t.co/G0rPH6Mpz8',
# ...

# %% [markdown]
# Dump to text

# %%
with open('sensus_penduduk_tweets.txt', 'w+') as f:
    f.write('\n'.join(searched_tweets))
